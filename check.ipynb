# %% [markdown]
# <a href="https://colab.research.google.com/github/HM-Mahibullah/googlecolab/blob/main/check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
print("ikkkkkkkkkkk")
# Out:
# hello
# ikkkkkkkkkkk
